# %% [markdown]
# <a href="https://colab.research.google.com/github/milkyme/DSlab_practice/blob/main/MovementDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import os
import numpy as np
import pandas as pd

# %%
data_path = ['/content/drive/My Drive/Colab Notebooks/data_source']
train_x_path = os.sep.join(data_path + ['X_train.txt'])
train_y_path = os.sep.join(data_path + ['y_train.txt'])
train_x_data = pd.read_csv(train_x_path, sep = '\s+', header = None)
train_y_data = pd.read_csv(train_y_path, sep = '\s+', header = None)

frames = [train_x_data, train_y_data]
dataframe = pd.concat(frames, axis = 1, keys = ["x", "y"]) # X : 7352*561, Y : 7352*1

# %%
dataframe.describe()
# Out:
#                  x               ...                         y
#                0            1    ...          560          0
# count  7352.000000  7352.000000  ...  7352.000000  7352.000000
# mean      0.274488    -0.017695  ...    -0.056515     3.643362
# std       0.070261     0.040811  ...     0.279122     1.744802
# min      -1.000000    -1.000000  ...    -1.000000     1.000000
# 25%       0.262975    -0.024863  ...    -0.143414     2.000000
# 50%       0.277193    -0.017219  ...     0.003181     4.000000
# 75%       0.288461    -0.010783  ...     0.107659     5.000000
# max       1.000000     1.000000  ...     1.000000     6.000000
#
# [8 rows x 562 columns]

# %%
test_x_path = os.sep.join(data_path + ['X_test.txt'])
test_y_path = os.sep.join(data_path + ['y_test.txt'])
test_x_data = pd.read_csv(test_x_path, sep = '\s+', header = None)
test_y_data = pd.read_csv(test_y_path, sep = '\s+', header = None)

frames = [test_x_data, test_y_data]
dataframe = pd.concat(frames, axis = 1, keys = ["x", "y"]) # X : 7352*561, Y : 7352*1

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(64, activation='sigmoid'),
    keras.layers.Dense(7, activation='sigmoid')
])

model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_x_data, train_y_data, epochs=10, validation_data=(test_x_data, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 2s 6ms/step - loss: 1.1364 - accuracy: 0.5619 - val_loss: 0.3858 - val_accuracy: 0.8660
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2795 - accuracy: 0.9156 - val_loss: 0.2143 - val_accuracy: 0.9291
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1500 - accuracy: 0.9514 - val_loss: 0.1972 - val_accuracy: 0.9304
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1136 - accuracy: 0.9594 - val_loss: 0.1746 - val_accuracy: 0.9335
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0860 - accuracy: 0.9682 - val_loss: 0.1412 - val_accuracy: 0.9488
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0794 - accuracy: 0.9729 - val_loss: 0.2365 - val_accuracy: 0.9067
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

class MyModel(tf.keras.Model):

  def __init__(self):
    super(MyModel, self).__init__()
    self.dense1 = tf.keras.layers.Dense(256, activation='sigmoid')
    self.dense2 = tf.keras.layers.Dense(64, activation='sigmoid')
    self.dense3 = tf.keras.layers.Dense(7, activation='sigmoid')


  def call(self, inputs):
    x1 = self.dense1(inputs)
    x2 = self.dense2(x1)
    return self.dense3(x2)

model = MyModel()

model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_x_data, train_y_data, epochs=10, validation_data=(test_x_data, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 2s 5ms/step - loss: 1.1660 - accuracy: 0.5663 - val_loss: 0.4503 - val_accuracy: 0.8151
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2936 - accuracy: 0.9054 - val_loss: 0.2177 - val_accuracy: 0.9345
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1716 - accuracy: 0.9412 - val_loss: 0.2318 - val_accuracy: 0.9016
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9631 - val_loss: 0.1656 - val_accuracy: 0.9355
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0925 - accuracy: 0.9698 - val_loss: 0.1789 - val_accuracy: 0.9338
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0898 - accuracy: 0.9704 - val_loss: 0.1407 - val_accuracy: 0.9498
# Epoch 7/10
# ...

# %%
train_x_data_tBodyAcc = train_x_data.iloc[:,40:]
train_x_data_GravityAcc = pd.concat([train_x_data.iloc[:, :40], train_x_data.iloc[:, 80:]], axis = 1)
train_x_data_tBodyAccJerk = pd.concat([train_x_data.iloc[:, :80], train_x_data.iloc[:, 120:]], axis = 1)
train_x_data_tBodyGyro = pd.concat([train_x_data.iloc[:, :120], train_x_data.iloc[:, 160:]], axis = 1)
train_x_data_tBodyGyroJerk = pd.concat([train_x_data.iloc[:, :160], train_x_data.iloc[:, 200:]], axis = 1)

test_x_data_tBodyAcc = test_x_data.iloc[:,40:]
test_x_data_GravityAcc = pd.concat([test_x_data.iloc[:, :40], test_x_data.iloc[:, 80:]], axis = 1)
test_x_data_tBodyAccJerk = pd.concat([test_x_data.iloc[:, :80], test_x_data.iloc[:, 120:]], axis = 1)
test_x_data_tBodyGyro = pd.concat([test_x_data.iloc[:, :120], test_x_data.iloc[:, 160:]], axis = 1)
test_x_data_tBodyGyroJerk = pd.concat([test_x_data.iloc[:, :160], test_x_data.iloc[:, 200:]], axis = 1)

# %%
model_tBodyAcc = MyModel()
model_tBodyAcc.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyAcc.fit(train_x_data_tBodyAcc, train_y_data, epochs=10, validation_data=(test_x_data_tBodyAcc, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.2007 - accuracy: 0.5367 - val_loss: 0.3847 - val_accuracy: 0.9006
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2861 - accuracy: 0.9176 - val_loss: 0.2597 - val_accuracy: 0.9077
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1797 - accuracy: 0.9328 - val_loss: 0.2006 - val_accuracy: 0.9274
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1195 - accuracy: 0.9559 - val_loss: 0.1713 - val_accuracy: 0.9376
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0966 - accuracy: 0.9652 - val_loss: 0.1815 - val_accuracy: 0.9270
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0787 - accuracy: 0.9724 - val_loss: 0.1540 - val_accuracy: 0.9410
# Epoch 7/10
# ...

# %%
model_GravityAcc = MyModel()
model_GravityAcc.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_GravityAcc.fit(train_x_data_GravityAcc, train_y_data, epochs=10, validation_data=(test_x_data_GravityAcc, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.2850 - accuracy: 0.5005 - val_loss: 0.5347 - val_accuracy: 0.7798
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4089 - accuracy: 0.8596 - val_loss: 0.3463 - val_accuracy: 0.8666
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2467 - accuracy: 0.9123 - val_loss: 0.2127 - val_accuracy: 0.9291
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1640 - accuracy: 0.9421 - val_loss: 0.2627 - val_accuracy: 0.8884
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1529 - accuracy: 0.9398 - val_loss: 0.2211 - val_accuracy: 0.9141
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1116 - accuracy: 0.9581 - val_loss: 0.1683 - val_accuracy: 0.9427
# Epoch 7/10
# ...

# %%
model_tBodyAccJerk = MyModel()
model_tBodyAccJerk.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyAccJerk.fit(train_x_data_tBodyAccJerk, train_y_data, epochs=10, validation_data=(test_x_data_tBodyAccJerk, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.2159 - accuracy: 0.5558 - val_loss: 0.4042 - val_accuracy: 0.8860
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2993 - accuracy: 0.9136 - val_loss: 0.2648 - val_accuracy: 0.9087
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1740 - accuracy: 0.9435 - val_loss: 0.2034 - val_accuracy: 0.9264
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1211 - accuracy: 0.9569 - val_loss: 0.2160 - val_accuracy: 0.9114
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0963 - accuracy: 0.9659 - val_loss: 0.1646 - val_accuracy: 0.9348
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0830 - accuracy: 0.9720 - val_loss: 0.1932 - val_accuracy: 0.9304
# Epoch 7/10
# ...

# %%
model_tBodyGyro = MyModel()
model_tBodyGyro.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyGyro.fit(train_x_data_tBodyGyro, train_y_data, epochs=10, validation_data=(test_x_data_tBodyGyro, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 2s 5ms/step - loss: 1.2101 - accuracy: 0.5386 - val_loss: 0.4094 - val_accuracy: 0.8670
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3116 - accuracy: 0.8984 - val_loss: 0.2620 - val_accuracy: 0.8996
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1712 - accuracy: 0.9464 - val_loss: 0.2669 - val_accuracy: 0.8924
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1300 - accuracy: 0.9507 - val_loss: 0.2052 - val_accuracy: 0.9128
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1137 - accuracy: 0.9587 - val_loss: 0.1613 - val_accuracy: 0.9399
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0848 - accuracy: 0.9666 - val_loss: 0.2938 - val_accuracy: 0.8806
# Epoch 7/10
# ...

# %%
model_tBodyGyroJerk = MyModel()
model_tBodyGyroJerk.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyGyroJerk.fit(train_x_data_tBodyGyroJerk, train_y_data, epochs=10, validation_data=(test_x_data_tBodyGyroJerk, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1553 - accuracy: 0.5537 - val_loss: 0.4428 - val_accuracy: 0.8307
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3086 - accuracy: 0.8968 - val_loss: 0.2416 - val_accuracy: 0.9084
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1784 - accuracy: 0.9367 - val_loss: 0.1992 - val_accuracy: 0.9264
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1314 - accuracy: 0.9521 - val_loss: 0.2055 - val_accuracy: 0.9158
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1042 - accuracy: 0.9615 - val_loss: 0.1818 - val_accuracy: 0.9270
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0964 - accuracy: 0.9634 - val_loss: 0.1998 - val_accuracy: 0.9274
# Epoch 7/10
# ...

# %%
train_x_data_tBodyAccMag = pd.concat([train_x_data.iloc[:, :200], train_x_data.iloc[:, 213:]], axis = 1)
train_x_data_tGravityAccMag = pd.concat([train_x_data.iloc[:, :213], train_x_data.iloc[:, 226:]], axis = 1)
train_x_data_tBodyAccJerkMag = pd.concat([train_x_data.iloc[:, :226], train_x_data.iloc[:, 239:]], axis = 1)
train_x_data_tBodyGyroMag = pd.concat([train_x_data.iloc[:, :239], train_x_data.iloc[:, 252:]], axis = 1)
train_x_data_tBodyGyroJerkMag = pd.concat([train_x_data.iloc[:, :252], train_x_data.iloc[:, 265:]], axis = 1)

test_x_data_tBodyAccMag = pd.concat([test_x_data.iloc[:, :200], test_x_data.iloc[:, 213:]], axis = 1)
test_x_data_tGravityAccMag = pd.concat([test_x_data.iloc[:, :213], test_x_data.iloc[:, 226:]], axis = 1)
test_x_data_tBodyAccJerkMag = pd.concat([test_x_data.iloc[:, :226], test_x_data.iloc[:, 239:]], axis = 1)
test_x_data_tBodyGyroMag = pd.concat([test_x_data.iloc[:, :239], test_x_data.iloc[:, 252:]], axis = 1)
test_x_data_tBodyGyroJerkMag = pd.concat([test_x_data.iloc[:, :252], test_x_data.iloc[:, 265:]], axis = 1)

# %%
model_tBodyAccMag = MyModel()
model_tBodyAccMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyAccMag.fit(train_x_data_tBodyAccMag, train_y_data, epochs=10, validation_data=(test_x_data_tBodyAccMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1231 - accuracy: 0.5925 - val_loss: 0.3568 - val_accuracy: 0.8999
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2731 - accuracy: 0.9151 - val_loss: 0.2192 - val_accuracy: 0.9260
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1624 - accuracy: 0.9448 - val_loss: 0.1816 - val_accuracy: 0.9342
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1077 - accuracy: 0.9641 - val_loss: 0.1607 - val_accuracy: 0.9437
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0855 - accuracy: 0.9695 - val_loss: 0.1356 - val_accuracy: 0.9515
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0773 - accuracy: 0.9718 - val_loss: 0.1611 - val_accuracy: 0.9389
# Epoch 7/10
# ...

# %%
model_tGravityAccMag = MyModel()
model_tGravityAccMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tGravityAccMag.fit(train_x_data_tGravityAccMag, train_y_data, epochs=10, validation_data=(test_x_data_tGravityAccMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1423 - accuracy: 0.5787 - val_loss: 0.4166 - val_accuracy: 0.8283
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2881 - accuracy: 0.9111 - val_loss: 0.2397 - val_accuracy: 0.8996
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1518 - accuracy: 0.9521 - val_loss: 0.1658 - val_accuracy: 0.9393
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1036 - accuracy: 0.9665 - val_loss: 0.2530 - val_accuracy: 0.8931
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0855 - accuracy: 0.9715 - val_loss: 0.1700 - val_accuracy: 0.9359
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0723 - accuracy: 0.9742 - val_loss: 0.1637 - val_accuracy: 0.9382
# Epoch 7/10
# ...

# %%
model_tBodyAccJerkMag = MyModel()
model_tBodyAccJerkMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyAccJerkMag.fit(train_x_data_tBodyAccJerkMag, train_y_data, epochs=10, validation_data=(test_x_data_tBodyAccJerkMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.2658 - accuracy: 0.5403 - val_loss: 0.4012 - val_accuracy: 0.8928
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3070 - accuracy: 0.9056 - val_loss: 0.2422 - val_accuracy: 0.9057
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1594 - accuracy: 0.9465 - val_loss: 0.2168 - val_accuracy: 0.9141
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1083 - accuracy: 0.9653 - val_loss: 0.1638 - val_accuracy: 0.9406
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0919 - accuracy: 0.9649 - val_loss: 0.1588 - val_accuracy: 0.9406
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0753 - accuracy: 0.9750 - val_loss: 0.1313 - val_accuracy: 0.9522
# Epoch 7/10
# ...

# %%
model_tBodyGyroMag = MyModel()
model_tBodyGyroMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyGyroMag.fit(train_x_data_tBodyGyroMag, train_y_data, epochs=10, validation_data=(test_x_data_tBodyGyroMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1732 - accuracy: 0.5671 - val_loss: 0.4191 - val_accuracy: 0.8697
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2937 - accuracy: 0.9019 - val_loss: 0.2259 - val_accuracy: 0.9240
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1631 - accuracy: 0.9440 - val_loss: 0.1928 - val_accuracy: 0.9240
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1053 - accuracy: 0.9642 - val_loss: 0.1843 - val_accuracy: 0.9379
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0915 - accuracy: 0.9675 - val_loss: 0.1501 - val_accuracy: 0.9427
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0700 - accuracy: 0.9765 - val_loss: 0.1493 - val_accuracy: 0.9410
# Epoch 7/10
# ...

# %%
model_tBodyGyroJerkMag = MyModel()
model_tBodyGyroJerkMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_tBodyGyroJerkMag.fit(train_x_data_tBodyGyroJerkMag, train_y_data, epochs=10, validation_data=(test_x_data_tBodyGyroJerkMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1356 - accuracy: 0.5754 - val_loss: 0.4214 - val_accuracy: 0.8646
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2788 - accuracy: 0.9170 - val_loss: 0.2291 - val_accuracy: 0.9186
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1543 - accuracy: 0.9513 - val_loss: 0.2002 - val_accuracy: 0.9250
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1212 - accuracy: 0.9587 - val_loss: 0.1767 - val_accuracy: 0.9332
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0802 - accuracy: 0.9733 - val_loss: 0.1506 - val_accuracy: 0.9413
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0884 - accuracy: 0.9675 - val_loss: 0.1959 - val_accuracy: 0.9240
# Epoch 7/10
# ...

# %%
train_x_data_fBodyAcc = pd.concat([train_x_data.iloc[:, :265], train_x_data.iloc[:, 344:]], axis = 1)
train_x_data_fBodyAccJerk = pd.concat([train_x_data.iloc[:, :344], train_x_data.iloc[:, 423:]], axis = 1)
train_x_data_fBodyGyro = pd.concat([train_x_data.iloc[:, :423], train_x_data.iloc[:, 502:]], axis = 1)

test_x_data_fBodyAcc = pd.concat([test_x_data.iloc[:, :265], test_x_data.iloc[:, 344:]], axis = 1)
test_x_data_fBodyAccJerk = pd.concat([test_x_data.iloc[:, :344], test_x_data.iloc[:, 423:]], axis = 1)
test_x_data_fBodyGyro = pd.concat([test_x_data.iloc[:, :423], test_x_data.iloc[:, 502:]], axis = 1)

# %%
model_fBodyAcc = MyModel()
model_fBodyAcc.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyAcc.fit(train_x_data_fBodyAcc, train_y_data, epochs=10, validation_data=(test_x_data_fBodyAcc, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1534 - accuracy: 0.5689 - val_loss: 0.4212 - val_accuracy: 0.8317
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2964 - accuracy: 0.9063 - val_loss: 0.2168 - val_accuracy: 0.9250
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1578 - accuracy: 0.9467 - val_loss: 0.1787 - val_accuracy: 0.9396
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1016 - accuracy: 0.9659 - val_loss: 0.1625 - val_accuracy: 0.9389
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0934 - accuracy: 0.9669 - val_loss: 0.1875 - val_accuracy: 0.9220
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0731 - accuracy: 0.9743 - val_loss: 0.1830 - val_accuracy: 0.9325
# Epoch 7/10
# ...

# %%
model_fBodyAccJerk = MyModel()
model_fBodyAccJerk.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyAccJerk.fit(train_x_data_fBodyAccJerk, train_y_data, epochs=10, validation_data=(test_x_data_fBodyAccJerk, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1134 - accuracy: 0.5961 - val_loss: 0.3823 - val_accuracy: 0.8829
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2745 - accuracy: 0.9204 - val_loss: 0.2065 - val_accuracy: 0.9338
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1449 - accuracy: 0.9522 - val_loss: 0.1809 - val_accuracy: 0.9287
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1059 - accuracy: 0.9647 - val_loss: 0.1804 - val_accuracy: 0.9287
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0825 - accuracy: 0.9733 - val_loss: 0.1628 - val_accuracy: 0.9382
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0730 - accuracy: 0.9755 - val_loss: 0.1486 - val_accuracy: 0.9444
# Epoch 7/10
# ...

# %%
model_fBodyGyro = MyModel()
model_fBodyGyro.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyGyro.fit(train_x_data_fBodyGyro, train_y_data, epochs=10, validation_data=(test_x_data_fBodyGyro, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1456 - accuracy: 0.5815 - val_loss: 0.3986 - val_accuracy: 0.8860
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3050 - accuracy: 0.9038 - val_loss: 0.2506 - val_accuracy: 0.9030
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1696 - accuracy: 0.9449 - val_loss: 0.2337 - val_accuracy: 0.9179
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1203 - accuracy: 0.9610 - val_loss: 0.2617 - val_accuracy: 0.8992
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0989 - accuracy: 0.9657 - val_loss: 0.2532 - val_accuracy: 0.9063
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1099 - accuracy: 0.9614 - val_loss: 0.1650 - val_accuracy: 0.9413
# Epoch 7/10
# ...

# %%
train_x_data_fBodyAccMag = pd.concat([train_x_data.iloc[:, :502], train_x_data.iloc[:, 515:]], axis = 1)
train_x_data_fBodyBodyAccJerkMag = pd.concat([train_x_data.iloc[:, :515], train_x_data.iloc[:, 528:]], axis = 1)
train_x_data_fBodyBodyGyroMag = pd.concat([train_x_data.iloc[:, :528], train_x_data.iloc[:, 541:]], axis = 1)
train_x_data_fBodyBodyGyroJerkMag = pd.concat([train_x_data.iloc[:, :541], train_x_data.iloc[:, 554:]], axis = 1)
train_x_data_angle = train_x_data.iloc[:, :554]

test_x_data_fBodyAccMag = pd.concat([test_x_data.iloc[:, :502], test_x_data.iloc[:, 515:]], axis = 1)
test_x_data_fBodyBodyAccJerkMag = pd.concat([test_x_data.iloc[:, :515], test_x_data.iloc[:, 528:]], axis = 1)
test_x_data_fBodyBodyGyroMag = pd.concat([test_x_data.iloc[:, :528], test_x_data.iloc[:, 541:]], axis = 1)
test_x_data_fBodyBodyGyroJerkMag = pd.concat([test_x_data.iloc[:, :541], test_x_data.iloc[:, 554:]], axis = 1)
test_x_data_angle = test_x_data.iloc[:, :554]

# %%
model_fBodyAccMag = MyModel()
model_fBodyAccMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyAccMag.fit(train_x_data_fBodyAccMag, train_y_data, epochs=10, validation_data=(test_x_data_fBodyAccMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.2451 - accuracy: 0.5101 - val_loss: 0.4015 - val_accuracy: 0.8877
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2828 - accuracy: 0.9178 - val_loss: 0.2743 - val_accuracy: 0.8870
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1523 - accuracy: 0.9503 - val_loss: 0.1657 - val_accuracy: 0.9410
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1220 - accuracy: 0.9594 - val_loss: 0.1785 - val_accuracy: 0.9308
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0890 - accuracy: 0.9671 - val_loss: 0.2103 - val_accuracy: 0.9155
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0738 - accuracy: 0.9763 - val_loss: 0.2291 - val_accuracy: 0.9125
# Epoch 7/10
# ...

# %%
model_fBodyBodyAccJerkMag = MyModel()
model_fBodyBodyAccJerkMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyBodyAccJerkMag.fit(train_x_data_fBodyBodyAccJerkMag, train_y_data, epochs=10, validation_data=(test_x_data_fBodyBodyAccJerkMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.3142 - accuracy: 0.5179 - val_loss: 0.4140 - val_accuracy: 0.8442
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3008 - accuracy: 0.9111 - val_loss: 0.2992 - val_accuracy: 0.8690
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1680 - accuracy: 0.9476 - val_loss: 0.2084 - val_accuracy: 0.9114
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1236 - accuracy: 0.9564 - val_loss: 0.1803 - val_accuracy: 0.9315
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0930 - accuracy: 0.9662 - val_loss: 0.1511 - val_accuracy: 0.9427
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0836 - accuracy: 0.9699 - val_loss: 0.2303 - val_accuracy: 0.9101
# Epoch 7/10
# ...

# %%
model_fBodyBodyGyroMag = MyModel()
model_fBodyBodyGyroMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyBodyGyroMag.fit(train_x_data_fBodyBodyGyroMag, train_y_data, epochs=10, validation_data=(test_x_data_fBodyBodyGyroMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1592 - accuracy: 0.5723 - val_loss: 0.3886 - val_accuracy: 0.8958
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2882 - accuracy: 0.9218 - val_loss: 0.2141 - val_accuracy: 0.9379
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1676 - accuracy: 0.9424 - val_loss: 0.1721 - val_accuracy: 0.9352
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1069 - accuracy: 0.9631 - val_loss: 0.1378 - val_accuracy: 0.9511
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0950 - accuracy: 0.9663 - val_loss: 0.2384 - val_accuracy: 0.9033
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0996 - accuracy: 0.9624 - val_loss: 0.1599 - val_accuracy: 0.9420
# Epoch 7/10
# ...

# %%
model_fBodyBodyGyroJerkMag = MyModel()
model_fBodyBodyGyroJerkMag.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_fBodyBodyGyroJerkMag.fit(train_x_data_fBodyBodyGyroJerkMag, train_y_data, epochs=10, validation_data=(test_x_data_fBodyBodyGyroJerkMag, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.2059 - accuracy: 0.5585 - val_loss: 0.3574 - val_accuracy: 0.9026
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2855 - accuracy: 0.9093 - val_loss: 0.2359 - val_accuracy: 0.9036
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1617 - accuracy: 0.9480 - val_loss: 0.1846 - val_accuracy: 0.9332
# Epoch 4/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1103 - accuracy: 0.9618 - val_loss: 0.1579 - val_accuracy: 0.9410
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0785 - accuracy: 0.9747 - val_loss: 0.2002 - val_accuracy: 0.9209
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.0912 - accuracy: 0.9682 - val_loss: 0.1446 - val_accuracy: 0.9460
# Epoch 7/10
# ...

# %%
model_angle = MyModel()
model_angle.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_angle.fit(train_x_data_angle, train_y_data, epochs=10, validation_data=(test_x_data_angle, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 5ms/step - loss: 1.1501 - accuracy: 0.5744 - val_loss: 0.3907 - val_accuracy: 0.8636
# Epoch 2/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2854 - accuracy: 0.9078 - val_loss: 0.2204 - val_accuracy: 0.9199
# Epoch 3/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1688 - accuracy: 0.9423 - val_loss: 0.2077 - val_accuracy: 0.9328
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1117 - accuracy: 0.9593 - val_loss: 0.1785 - val_accuracy: 0.9342
# Epoch 5/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0987 - accuracy: 0.9643 - val_loss: 0.1613 - val_accuracy: 0.9399
# Epoch 6/10
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0935 - accuracy: 0.9648 - val_loss: 0.1488 - val_accuracy: 0.9444
# Epoch 7/10
# ...

# %%
train_x_data_Acc = pd.concat([train_x_data.iloc[:, :120], train_x_data.iloc[:, 200:239], train_x_data.iloc[:, 265:423], train_x_data.iloc[:, 502:528]], axis = 1)
train_x_data_Gyro = pd.concat([train_x_data.iloc[:, 120:200], train_x_data.iloc[:, 239:265], train_x_data.iloc[:, 423:502], train_x_data.iloc[:, 528:554]], axis = 1)
train_x_data_Angle = train_x_data.iloc[:, 554:]
train_x_data_AccAngle = pd.concat([train_x_data.iloc[:, :120], train_x_data.iloc[:, 200:239], train_x_data.iloc[:, 265:423], train_x_data.iloc[:, 502:528], train_x_data.iloc[:, 554:]], axis = 1)
train_x_data_GyroAngle = pd.concat([train_x_data.iloc[:, 120:200], train_x_data.iloc[:, 239:265], train_x_data.iloc[:, 423:502], train_x_data.iloc[:, 528:]], axis = 1)


test_x_data_Acc = pd.concat([test_x_data.iloc[:, :120], test_x_data.iloc[:, 200:239], test_x_data.iloc[:, 265:423], test_x_data.iloc[:, 502:528]], axis = 1)
test_x_data_Gyro = pd.concat([test_x_data.iloc[:, 120:200], test_x_data.iloc[:, 239:265], test_x_data.iloc[:, 423:502], test_x_data.iloc[:, 528:554]], axis = 1)
test_x_data_Angle = test_x_data.iloc[:, 554:]
test_x_data_AccAngle = pd.concat([test_x_data.iloc[:, :120], test_x_data.iloc[:, 200:239], test_x_data.iloc[:, 265:423], test_x_data.iloc[:, 502:528], test_x_data.iloc[:, 554:]], axis = 1)
test_x_data_GyroAngle = pd.concat([test_x_data.iloc[:, 120:200], test_x_data.iloc[:, 239:265], test_x_data.iloc[:, 423:502], test_x_data.iloc[:, 528:]], axis = 1)

# %%
model_Acc = MyModel()
model_Acc.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_Acc.fit(train_x_data_Acc, train_y_data, epochs=10, validation_data=(test_x_data_Acc, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.2059 - accuracy: 0.5645 - val_loss: 0.4574 - val_accuracy: 0.8453
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3445 - accuracy: 0.8790 - val_loss: 0.3214 - val_accuracy: 0.8636
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2374 - accuracy: 0.9102 - val_loss: 0.2768 - val_accuracy: 0.8877
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1943 - accuracy: 0.9239 - val_loss: 0.3047 - val_accuracy: 0.8690
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1726 - accuracy: 0.9306 - val_loss: 0.2779 - val_accuracy: 0.8921
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1478 - accuracy: 0.9386 - val_loss: 0.2695 - val_accuracy: 0.8918
# Epoch 7/10
# ...

# %%
model_Gyro = MyModel()
model_Gyro.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_Gyro.fit(train_x_data_Gyro, train_y_data, epochs=10, validation_data=(test_x_data_Gyro, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4895 - accuracy: 0.3652 - val_loss: 0.9458 - val_accuracy: 0.6138
# Epoch 2/10
# 230/230 [==============================] - 1s 2ms/step - loss: 0.8993 - accuracy: 0.6085 - val_loss: 0.7384 - val_accuracy: 0.7082
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.6968 - accuracy: 0.7029 - val_loss: 0.6493 - val_accuracy: 0.7391
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.6084 - accuracy: 0.7514 - val_loss: 0.6150 - val_accuracy: 0.7591
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.5551 - accuracy: 0.7762 - val_loss: 0.5984 - val_accuracy: 0.7567
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.5210 - accuracy: 0.7897 - val_loss: 0.5815 - val_accuracy: 0.7553
# Epoch 7/10
# ...

# %%
model_Angle = MyModel()
model_Angle.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_Angle.fit(train_x_data_Angle, train_y_data, epochs=10, validation_data=(test_x_data_Angle, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 3ms/step - loss: 1.8170 - accuracy: 0.2589 - val_loss: 1.4575 - val_accuracy: 0.4045
# Epoch 2/10
# 230/230 [==============================] - 0s 2ms/step - loss: 1.3724 - accuracy: 0.3967 - val_loss: 1.3108 - val_accuracy: 0.4276
# Epoch 3/10
# 230/230 [==============================] - 0s 2ms/step - loss: 1.2581 - accuracy: 0.4512 - val_loss: 1.2625 - val_accuracy: 0.4177
# Epoch 4/10
# 230/230 [==============================] - 0s 2ms/step - loss: 1.1895 - accuracy: 0.4709 - val_loss: 1.2156 - val_accuracy: 0.4829
# Epoch 5/10
# 230/230 [==============================] - 0s 2ms/step - loss: 1.1209 - accuracy: 0.5189 - val_loss: 1.1697 - val_accuracy: 0.5117
# Epoch 6/10
# 230/230 [==============================] - 1s 2ms/step - loss: 1.0709 - accuracy: 0.5399 - val_loss: 1.1546 - val_accuracy: 0.5131
# Epoch 7/10
# ...

# %%
model_AccAngle = MyModel()
model_AccAngle.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_AccAngle.fit(train_x_data_AccAngle, train_y_data, epochs=10, validation_data=(test_x_data_AccAngle, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1966 - accuracy: 0.5771 - val_loss: 0.4463 - val_accuracy: 0.8314
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3408 - accuracy: 0.8780 - val_loss: 0.3258 - val_accuracy: 0.8785
# Epoch 3/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2341 - accuracy: 0.9121 - val_loss: 0.3090 - val_accuracy: 0.8687
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1836 - accuracy: 0.9280 - val_loss: 0.2645 - val_accuracy: 0.8968
# Epoch 5/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1738 - accuracy: 0.9293 - val_loss: 0.2831 - val_accuracy: 0.8839
# Epoch 6/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1512 - accuracy: 0.9406 - val_loss: 0.3153 - val_accuracy: 0.8806
# Epoch 7/10
# ...

# %%
model_GyroAngle = MyModel()
model_GyroAngle.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model_GyroAngle.fit(train_x_data_GyroAngle, train_y_data, epochs=10, validation_data=(test_x_data_GyroAngle, test_y_data))
# Out:
# Epoch 1/10
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4991 - accuracy: 0.3475 - val_loss: 0.8141 - val_accuracy: 0.7055
# Epoch 2/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.6827 - accuracy: 0.7725 - val_loss: 0.4734 - val_accuracy: 0.8456
# Epoch 3/10
# 230/230 [==============================] - 1s 2ms/step - loss: 0.4099 - accuracy: 0.8589 - val_loss: 0.3741 - val_accuracy: 0.8646
# Epoch 4/10
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3163 - accuracy: 0.8878 - val_loss: 0.3388 - val_accuracy: 0.8711
# Epoch 5/10
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2512 - accuracy: 0.9095 - val_loss: 0.3325 - val_accuracy: 0.8694
# Epoch 6/10
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2011 - accuracy: 0.9314 - val_loss: 0.3406 - val_accuracy: 0.8697
# Epoch 7/10
# ...
